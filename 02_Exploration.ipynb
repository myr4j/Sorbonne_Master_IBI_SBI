# %% [markdown]
# # **Nettoyage de données**
# Ce document présente quelques exercices d'exploration des données.
# Il a pour but de vous faire découvrir les manipulations de bases et courantes.
# Parmi toutes les questions, certaines solutions ne sont disponibles dans aucun document de cours. C'est normal.
# Il vous faudra trouver la solution en vous renseignant sur internet, qu'importe l'outil.
#
# Il est cependant STRICTEMENT INTERDIT :
#     <br>- De passer tout ou partie du jeu de données à un LLM
#     <br>- De charger le jeu de données sur un cloud ou un support autre que votre PC personnel.
# Ces données sont privées et les révéler vous expose à des poursuites.

# %% [markdown]
# **0 - Charger les données**
# Commencez par charger les données des fichiers :
# - data/clean_step_1.pkl

# %% [markdown]
# **1 - Clé unique.**
# Existe-t'il des valeurs en double dans la colonne pid ?
# Même question en détaillant par pid et vague_cine_inv, puis par pid et vague_cine_inv et âge.

# %%
#Réponse attendue : np.int64(3467)

# %%
#Réponse attendue : np.int64(2746)

# %%
#Réponse attendue : np.int64(1258)

# %% [markdown]
# Filtrez le lignes telles que pid == 1488283857, vague_cine_inv == 2329 et age == 67.
# Quelles sont les colonnes pour lesquelles les valeurs différent ? Déduisez ce que représente une ligne ?
# Donnez une combinaison de colonne, de préférence avec un sens business, qui garantit l'unicité d'une ligne.

# %% [markdown]
# **2 - Distributions de base.**
# Calculez les effectifs et proportions par :
# - Sexe
# - Habitude de frequentation
# - Régions marketing en 5 et en 9
# - Type d'agglomération
# - Vague cinéma

# %%
# Réponses attendues Effectif

# gender
# 1    4839
# 2    5407

# s3ad
# 1     688
# 2    1636
# 3    2525
# 4    2973
# 5    1739
# 6     460
# 7     125
# 8     100

# uda5
# 1    2596
# 2    2075
# 3    2366
# 4     983
# 5    2226

# uda9
# 1    2578
# 2     873
# 3     781
# 4     738
# 5     841
# 6    1237
# 7     961
# 8    1054
# 9    1183

# agglo_new
# 1    1366
# 2    1009
# 3     469
# 4     647
# 5     861
# 6     620
# 7    2907
# 8    2367

# vague_cine_inv
# 2326    1239
# 2327    2177
# 2328    1819
# 2329    2001
# 2330    2011
# 2331     999

# %%
# Réponses attendues Proportions

# gender
# 1    0.472282
# 2    0.527718

# s3ad
# 1    0.067148
# 2    0.159672
# 3    0.246438
# 4    0.290162
# 5    0.169725
# 6    0.044896
# 7    0.012200
# 8    0.009760

# uda5
# 1    0.253367
# 2    0.202518
# 3    0.230919
# 4    0.095940
# 5    0.217256

# uda9
# 1    0.251610
# 2    0.085204
# 3    0.076225
# 4    0.072028
# 5    0.082081
# 6    0.120730
# 7    0.093793
# 8    0.102869
# 9    0.115460

# agglo_new
# 1    0.133320
# 2    0.098477
# 3    0.045774
# 4    0.063147
# 5    0.084033
# 6    0.060511
# 7    0.283720
# 8    0.231017

# vague_cine_inv
# 2326    0.120925
# 2327    0.212473
# 2328    0.177533
# 2329    0.195296
# 2330    0.196272
# 2331    0.097501

# %% [markdown]
# **3 - Dates. 🌶️**
# Prenez la colonne de date, et extrayez le jour, le jour de la semaine, le mois et l'année
# avec les attributs : day, dayofweek, month, year. Pourquoi ça ne marche pas ?
# Cherchez une solution.
# Quels sont les jours de la semaine où on obtient le plus de réponse ?

# %%
# Réponse attendue : Quels sont les jours de la semaine où on obtient le plus de réponse ? 

# q1ad
# 0     865
# 1    1289
# 2    1714
# 3    1114
# 4    1119
# 5    2669
# 6    1476

# %% [markdown]
# **4 - Notes selon les comportements.**
# Calculez la moyenne et la médiane des notes attribuées par :
# - Habitude de fréquentation
# - Abonnement

# %%
# Réponse attendue : 
    # Habitude de fréquentation : 
        # Note moyenne 
            # s3ad
            # 1    7.763081
            # 2    8.071516
            # 3    8.038416
            # 4    7.967709
            # 5    7.794710
            # 6    7.604348
            # 7    7.552000
            # 8    6.810000
        # Note médiane
            # s3ad
            # 1    8.0
            # 2    8.0
            # 3    8.0
            # 4    8.0
            # 5    8.0
            # 6    8.0
            # 7    8.0
            # 8    8.0

    # Abonnement : 
        # Note moyenne 
            # s4ad
            # 1    7.738686
            # 2    7.956340
            # 3    7.954470
        # Note médiane
            # s4ad
            # 1    8.0
            # 2    8.0
            # 3    8.0

# %% [markdown]
# Construisez ensuite un tableau croisé Habitude de fréquentation × Abonnement avec la note moyenne.
# Quel segment attribue les meilleures notes ?

# %%
# Réponse attendue
# s4ad	1	        2	        3
# s3ad			
# 1	    7.553571	7.723077	8.044118
# 2	    7.868895	8.258947	8.058290
# 3	    7.851064	8.101215	8.062236
# 4	    7.805861	7.886207	7.995851
# 5	    7.500000	7.243902	7.837018
# 6	    6.307692	7.555556	7.649635
# 7	    6.750000	6.461538	7.790000
# 8	    5.333333	6.045455	7.246377

# %% [markdown]
# **5 - Profil du nombre de personnes par visite.**
# Décrivez la distribution du nombre de personnes lors de la sortie.
# Quelle part des visites sont en solo ? Comparer cette part par genre.

# %%
# Réponse attendue
# # q13ad
# 1    2117
# 2    4929
# 3    1714
# 4     994
# 5     265
# 6     227

# part_en_solo=20.66%

# %%
# Réponse attendue par genre
# q13ad	    1	    2	    3	4	5	6
# gender						
# 1	        1131	2249	793	449	114	103
# 2	        986	    2680	921	545	151	124

# part en solo par genre 
# gender
# 1    0.233726
# 2    0.182356

# %% [markdown]
# Comparez cette part par classes d’âge 🌶️. Pour cela, créez une colonne des classes d'âge suivantes :
# - 3-14
# - 15-24
# - 25-34
# - 35-49
# - 50-59
# - 60+

# %%
# Réponse attendue
# q13ad	    1	2	    3	4	5	6
# classe_age						
# 3-14	    180	804	    440	246	63	49
# 15-24	    324	820	    398	247	59	62
# 25-34	    216	515	    154	96	17	20
# 35-49	    553	1039	367	228	74	49
# 50-59	    375	745	    207	104	22	23
# 60+	    469	1006	148	73	30	24

# part solo par classe d'âge
# classe_age
# 3-14     0.101010
# 15-24    0.169634
# 25-34    0.212181
# 35-49    0.239394
# 50-59    0.254065
# 60+      0.268000

# %% [markdown]
# **6 - Mobilité vers les cinémas.**
# Comparez le département du répondant au département du cinéma.
# Quel pourcentage des visites a lieu hors du département de résidence ?

# %%
# Réponse attendue

# visite_int = 8761
# visite_ext = 1485
# 'Part de visite en dehors du département de résidence : 14.5%'

# %% [markdown]
# **7 - Joindre les poids statistiques.**
# Les calculs que nous avons faits précédemment reposent sur les répondants, où chaque ligne vaut 1.
# On parle de calcul sur effectif brut.
# C'est pratique, mais cela ne correspond pas nécessairement à la population de la France.
#
# Par exemple, dans le jeu de données, parmi les personnes ayant entre 15 et 19 ans inclus sont :
# - 54.0 % de femmes
# - 46.0 % d'hommes
#
# Or dans la population française, voici les valeur obtenues par l'INSEE :
# - 48.4 % de femmes
# - 51.6 % d'hommes
#
# Le rapport est inversé. Il faut donc appliquer un traitement statistique, appelée redressement,
# qui va permettre de se rapprocher de la bonne proportion dans le jeu de données.
#
# Une fois le redressement effectué, chaque ligne se verra attribuer un "poids", qui ne vaudra plus 1.
# Nous ne nous attarderons pas sur la méthodologie, qui n'est pas l'objet du cours.
# Nous allons cependant utiliser le redressment effectué par Vertigo, qui nous permettra d'obtenir les résultats publiés.

# %% [markdown]
# ### **Chargez les données des fichiers :**
# - data/poids_statistiques.csv
#
# A l'aide de la question 1, joignez les données des poids aux données nettoyées.
#     Attention à la différence entre pd.merge(), jointure sur les colonnes, et pd.join(), jointure sur les index.
#     Vous devez obtenir 9802 lignes dans le résultat.
#
# Si vous n'obtenez pas ce résultat, posez vous ces deux questions :
# - Ai-je bien respecté le caractère d'unicité des lignes ?
# - Ai-je choisi le bon type de jointure ?

# %%
# Réponse attendue : 
# DataFrame de 9802 rows × 23 columns

# %% [markdown]
# **8 - Recalculer la part des hommes et des femmes ayant entre 15 et 19 ans**
# En utilisant les poids statistiques à la place du nombre de lignes.
# Y a t'il une amélioration des proportions par rapport au calcul fait dans l'énoncé de la question 7 ?

# %%
# Réponse attendue 
# gender
# 1    0.512195
# 2    0.487805

# %% [markdown]
# **9 - Refaire les questions 2 et 4 🌶️ (seulement la note moyenne) en utilisant les poids statistiques.**

# %%
# Question 2 Effectif
# Réponse attendue 

# gender
# 1    9920735
# 2    9519455

# s3ad
# 1    1024646
# 2    2393547
# 3    4234973
# 4    4771958
# 5    5201341
# 6    1267052
# 7     362699
# 8     183972

# uda5
# 1    4332168
# 2    3898652
# 3    4345782
# 4    2407956
# 5    4455631

# uda9
# 1    4332168
# 2    1381005
# 3    1652770
# 4    1312005
# 5    1861340
# 6    2037311
# 7    2407956
# 8    1915068
# 9    2540562

# agglo_new
# 1    2762171
# 2    1917117
# 3     874265
# 4    1160120
# 5    1770668
# 6    1200891
# 7    5813851
# 8    3941105

# vague_cine_inv
# 2326    1626833
# 2327    3366913
# 2328    3204572
# 2329    4143874
# 2330    4773573
# 2331    2324423

# %%
# Question 2 Proportions
# Réponse attendue 

# gender
# 1    0.510321
# 2    0.489679

# s3ad
# 1    0.052708
# 2    0.123124
# 3    0.217846
# 4    0.245469
# 5    0.267556
# 6    0.065177
# 7    0.018657
# 8    0.009464

# uda5
# 1    0.222846
# 2    0.200546
# 3    0.223546
# 4    0.123865
# 5    0.229197

# uda9
# 1    0.222846
# 2    0.071039
# 3    0.085018
# 4    0.067489
# 5    0.095747
# 6    0.104799
# 7    0.123865
# 8    0.098511
# 9    0.130686

# agglo_new
# 1    0.142086
# 2    0.098616
# 3    0.044972
# 4    0.059676
# 5    0.091083
# 6    0.061774
# 7    0.299063
# 8    0.202730

# vague_cine_inv
# 2326    0.083684
# 2327    0.173193
# 2328    0.164843
# 2329    0.213160
# 2330    0.245552
# 2331    0.119568

# %%
# Question 4
# Réponse attendue
    # Habtiude de fréquentation
        # s3ad
        # 1    7.856541
        # 2    8.232216
        # 3    8.118312
        # 4    8.047217
        # 5    7.755096
        # 6    7.838734
        # 7    8.086952
        # 8    7.700692

    # Abonnement
        # s4ad
        # 1    7.892359
        # 2    8.096968
        # 3    7.972417


    # TCD Habitude x Abonnement
        # s4ad	1	        2	        3
        # s3ad			
        # 1	    7.724175	7.862096	8.030636
        # 2	    7.914701	8.415828	8.282590
        # 3	    8.002001	8.163571	8.130877
        # 4	    7.804504	8.078151	8.066815
        # 5	    7.732048	7.540722	7.765734
        # 6	    7.834460	7.740938	7.846328
        # 7	    8.807884	8.210060	8.016089
        # 8	    9.754679	7.972690	7.590742

# %% [markdown]
# **10 - Refaire les questions 5 et 6 en utilisant les poids statistiques.**

# %%
# Question 5
    # Réponse attendue
        # q13ad
        # 1    3492513
        # 2    9569512
        # 3    3382024
        # 4    1963563
        # 5     539369
        # 6     493208
    
        # part_solo_ponderee=17.97%


    # Réponse attendue par genre
        # q13ad	    1	    2	    3	    4	    5	    6
        # gender						
        # 1	        2043873	4718988	1704178	954002	234372	265319
        # 2	        1448639	4850523	1677845	1009560	304996	227889

        # Part en solo par genre
        # gender
        # 1    0.206020
        # 2    0.152177


    # Réponse attendue par classe d'âge
        # q13ad	    1	    2	    3	    4	    5	    6
        # classe_age						
        # 3-14	    200356	1347297	814743	433600	108027	92032
        # 15-24	    655637	1892502	818632	510682	172228	193506
        # 25-34	    492721	1471798	434751	262099	46672	56485
        # 35-49	    774537	1744060	580381	395359	126163	76349
        # 50-59	    510629	1220919	388443	200369	38083	22807
        # 60+	    858629	1892933	345072	161451	48194	52026

        # Part en solo par classe d'age
        # classe_age
        # 3-14     0.066873
        # 15-24    0.154515
        # 25-34    0.178230
        # 35-49    0.209513
        # 50-59    0.214437
        # 60+      0.255673

# %%
# Question 6
    # Réponse attendue
        # visite_int_stats = np.int32(16888174)
        # visite_ext_stats = np.int32(2552016)
        # 'Part de visite en dehors du département de résidence : 13.1%'
